# %%
from logging import raiseExceptions
from tokenize import Double
import networkx as nx
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import os
import numpy as np
import torch
torch.manual_seed(125)
import random
random.seed(125)
import torch_f as torch_f
from modelovae import Node, GRASSEncoder, GRASSDecoder, deserialize
import seaborn as sns
from matplotlib.ticker import MaxNLocator
import statistics
from scipy.stats import sem, t, wasserstein_distance

# %%
use_gpu = True
device = torch.device("cuda:0" if use_gpu and torch.cuda.is_available() else "cpu")

def count_fn(f):
    def wrapper(*args, **kwargs):
        wrapper.count += 1
        return f(*args, **kwargs)
    wrapper.count = 0
    return wrapper

# %%
def traverseleaves(root, leaves):
    if root is not None:
        traverseleaves(root.left, leaves)
        if root.is_leaf():
            leaves.append(root)
        traverseleaves(root.right, leaves)
        return

def traverse(root):
        if root is not None:
            traverse(root.left)
            root.radius=root.radius.reshape(4)
            traverse(root.right)
            return

def traverseradius(root, rlist):
    if root is not None:
        traverseradius(root.left, rlist)
        rlist.append(root.radius[3])
        print("radius", root.radius[3])
        traverseradius(root.right, rlist)
        return 

def traversefeatures(root, features):
    if root is not None:
        traversefeatures(root.left, features)
        features.append(root.radius[3].cpu().item())
        traversefeatures(root.right, features)
        return features

def traversefeatures2(root, features):
    if root is not None:
        traversefeatures2(root.left, features)
        features.append(root.radius[0][3].cpu().item())
        traversefeatures2(root.right, features)
        return features          

def traverse_conexiones(root, tree):
        """
        traverse function will print all the node in the tree.
        """
        if root is not None:
            traverse_conexiones(root.left, tree)
            if root.right is not None:
                tree.append((root.data, root.right.data))
            if root.left is not None:
                tree.append((root.data, root.left.data))
            traverse_conexiones(root.right, tree)
            return tree

@count_fn
def createNode(data, radius,left = None, right = None):
        """
        Utility function to create a node.
        """
        return Node(data, radius, left, right)
 


def read_tree(filename, dir):
    with open('./' +dir +'/' +filename, "r") as f:
        byte = f.read() 
        return byte

def numerar_nodos(root, count):
    if root is not None:
        numerar_nodos(root.left, count)
        root.data = len(count)
        count.append(1)
        numerar_nodos(root.right, count)
        return 

def number_nodes(data_loader, batch_size):
    n_no = []
    qzero = 0
    qOne = 0
    qtwo = 0
    for batch in data_loader:
        for tree in batch:
            tree = tree[0]
            count = []
            n = tree.count_nodes(tree, count)
            n_no.append(len(n))
            li = []
            tree.traverseInorderChilds(tree, li)
            zero = [a for a in li if a == 0]
            one = [a for a in li if a == 1]
            two = [a for a in li if a == 2]
            qzero += len(zero)
            qOne += len(one)
            qtwo += len(two)

    nprom = np.mean(n_no)
    qzero /= len(data_loader)*batch_size
    qOne /= len(data_loader)*batch_size
    qtwo /= len(data_loader)*batch_size
    if round(qzero) == 0:
        qzero = 1
    if round(qOne) == 0:
        qOne = 1
    if round(qtwo) == 0:
        qtwo = 1
    mult = torch.tensor([1/round(qzero),1/round(qOne),1/round(qtwo)], device = device)
    return mult

# %%
def decode_testing(v, max, decoder, mult, min):
    def decode_node(v, max, decoder, mult, min):

        cl = decoder.nodeClassifier(v)
        _, label = torch.max(cl, 1)
        label = label.data
        
        
        if label == 1 and createNode.count <= max:
            right, radius = decoder.internalDecoder(v)
                
            d = createNode(1, radius) 
            
            d.right = decode_node(right, max, decoder, mult, min)
            return d

        elif label == 2 and createNode.count <= max:
            left, right, radius = decoder.bifurcationDecoder(v)
                
            d = createNode(1, radius)
            
            d.right = decode_node(right, max, decoder, mult, min)
            d.left = decode_node(left, max, decoder, mult, min)
        
            return d

       
        elif label == 0 : ##output del classifier
            radio = decoder.featureDecoder(v)
            return createNode(1,radio)  
        

    createNode.count = 0
    v = decoder.sample_decoder(v)
    dec = decode_node (v, max, decoder, mult, min)

    return dec

# %%
def my_collate(batch):
    return batch


class tDataset(Dataset):
    def __init__(self, l, dir, transform=None):
        self.names = l
        self.transform = transform
        self.data = [] #lista con las strings de todos los arboles
        for file in self.names:
            self.data.append(read_tree(file, dir))
        self.trees = []

        for tree in self.data:
            deserial = deserialize(tree)
            self.trees.append(deserial)
            

    def __len__(self):
        return len(self.names)

    def __getitem__(self, idx):
        #file = self.names[idx]
        #string = read_tree(file)
        tree = self.trees[idx]
        name = self.names[idx]
        return tree

batch_size = 1

# %%
dataset_name = "Vascusynth"
p = str(5)
eps = str(0)+str(1)
d = "data/paper/" + dataset_name + "P" +p + "eps" + eps
print("d", d)
t_list = os.listdir(d)[:100]
print(len(t_list))
dataset = tDataset(t_list, d )
data_loader = DataLoader(dataset, batch_size = batch_size, shuffle=True, collate_fn=my_collate)
    
i = 0
d = None
d_nodos = []
n_bifo = []
for batch in data_loader:
    for input in batch:
        count = []
        numerar_nodos(input, count)
        d_nodos.append(len(count))
        li = []
        input.traverseInorderChilds(input, li)
        two = [a for a in li if a == 2]
        n_bifo.append(len(two))
# Out:
# d data/paper/VascusynthP5eps01
# 100

# %%
def distance(node1, node2):
    """
    Calculates the Euclidean distance between two nodes
    """
    if node1 is not None and node2 is not None:
        dist = ((node1.radius[0]-node2.radius[0])**2 + 
                (node1.radius[1]-node2.radius[1])**2 + 
                (node1.radius[2]-node2.radius[2])**2)**0.5
    else:
        dist = 0
    return dist

def tree_length(node):
    '''calcula el largo total del arbol'''
    if node is None:
        return 0

    stack = [(node, None)]
    length = 0

    while stack:
        curr, prev = stack.pop()

        if curr.left:
            stack.append((curr.left, curr))

        if curr.right:
            stack.append((curr.right, curr))

        if prev:
            length += distance(prev, curr)

    return length

def total_length(root, node, d):
    '''
    calcula la distancia del primer a ultimo nodo, arbol sin bifurcaciones
    '''
    if node.left:
        total_length(root, node.left, d)
    if node.isLeaf():
        #d = distance(root, node)
        d.append(distance(root, node))
        return 
    if node.right:
        total_length(root, node.right, d)

def total_path_length(node):
    """
    Calculates the total path length of the tree
    """
    if node is None:
        return 0
    else:
        return distance(node, node.left) + total_path_length(node.left) + distance(node, node.right) + total_path_length(node.right)

def tortuosity(root):
    """
    Calculates the tortuosity of the tree
    """
    total_path_length_value = total_path_length(root)
    d = []
    max_path_length_value = total_length(root,root, d)
    return total_path_length_value / d[0]

# %%
def tr(root):
        if root is not None:
            tr(root.left)
            root.radius[0][3]=root.radius[0][3]/10
            if root.radius[0][3]<0:
                root.radius[0][3]=0
            tr(root.right)
            return

# %%
enmax_palette = ["#FE7871", "#B50603"]

color_codes_wanted = ['pink', 'blue']
col = lambda x: enmax_palette[color_codes_wanted.index(x)]

# %%
tortuosidad = []
n_bif = []
largo = []
n_nodes = []
ratio_radios = []
for batch in data_loader:
    for input in batch:

        graph = nx.Graph()
        input.toGraph(graph, 0 , False, flag = 0)
        degree1 = []

        for node in graph.nodes():
            if graph.degree(node) == 1:
                degree1.append(node)
       
        caminos = [ nx.shortest_path( graph, degree1[0], t ) for t in degree1[1:] ]
    
        subarboles = []
        for g in caminos:
            grafo = nx.Graph()
            grafo.add_nodes_from(g)
            et = []
            for node in grafo.nodes:
                edge = graph[node]
                edges = [a for a in list(edge.keys()) if a in g]
                edge_tuple = [(a,b) for a,b in zip([node]*len(edges), edges) ]
                for tuple in edge_tuple:
                    et.append(tuple)
            grafo.add_edges_from(et)
    
            aRecorrer = []
            numeroNodoInicial = degree1[0]
            r = graph.nodes[numeroNodoInicial]['radio']
            rad = list(graph.nodes[numeroNodoInicial]['posicion'])
            rad.append(r)

            nodoRaiz = Node( numeroNodoInicial, radius =  rad )

            for vecino in grafo.neighbors( numeroNodoInicial ):
                if vecino != numeroNodoInicial:
                    aRecorrer.append( (vecino, numeroNodoInicial,nodoRaiz ) )
            
            while len(aRecorrer) != 0:
                nodoAAgregar, numeroNodoPadre,nodoPadre = aRecorrer.pop(0)
                r = graph.nodes[nodoAAgregar]['radio']
                rad = list(graph.nodes[nodoAAgregar]['posicion'])
                rad.append(r)
                nodoActual = Node( nodoAAgregar, radius =  rad)
                nodoPadre.agregarHijo( nodoActual )
                for vecino in grafo.neighbors( nodoAAgregar ):
                    if vecino != numeroNodoPadre:
                        aRecorrer.append( (vecino, nodoAAgregar,nodoActual) )
            subarboles.append(nodoRaiz)
            tortuosidad.append(tortuosity(nodoRaiz))
        li = []
        input.traverseInorderChilds(input, li)
        two = [a for a in li if a == 2]
        n_bif.append(len(two))
        total_path_length_value = tree_length(input)
        largo.append(total_path_length_value.cpu().item())
        count = []
        n = input.countNodes(input, count)
        n_nodes.append(len(n))
        features = []
        traversefeatures(input, features)
        ratio_radios.append(sum(features)/len(features))

# %%
i = 0
def calculo_generados(latent_size, Grassdecoder, mult, n=100):
    tortuosidad_generados = []
    n_bif_generados = []
    n_nodes_generados = []
    largo_generados = []
    ratio_radios_generados = []
    with torch.no_grad():
        for i in range(n):
            noise = torch.randn(batch_size, latent_size).to(device)
            generated_images = decode_testing(noise, 100, Grassdecoder, mult, 1)
            count = []
            numerar_nodos(generated_images, count)
            graph = nx.Graph()
            generated_images.toGraph(graph, 0 , True, flag = 0)
            degree1 = []

            for node in graph.nodes():
                if graph.degree(node) == 1:
                    degree1.append(node)
            caminos = [ nx.shortest_path( graph, degree1[0], t ) for t in degree1[1:] ]
            subarboles = []
            for g in caminos:
                grafo = nx.Graph()
                grafo.add_nodes_from(g)
                et = []
                for node in grafo.nodes:
                    edge = graph[node]
                    edges = [a for a in list(edge.keys()) if a in g]
                    edge_tuple = [(a,b) for a,b in zip([node]*len(edges), edges) ]
                    for tuple in edge_tuple:
                        et.append(tuple)
                grafo.add_edges_from(et)
        
                aRecorrer = []
                numeroNodoInicial = degree1[0]
                r = graph.nodes[numeroNodoInicial]['radio']
                rad = list(graph.nodes[numeroNodoInicial]['posicion'])
                rad.append(r)

                nodoRaiz = Node( numeroNodoInicial, radius =  rad )

                for vecino in grafo.neighbors( numeroNodoInicial ):
                    if vecino != numeroNodoInicial:
                        aRecorrer.append( (vecino, numeroNodoInicial,nodoRaiz ) )
                
                while len(aRecorrer) != 0:
                    nodoAAgregar, numeroNodoPadre,nodoPadre = aRecorrer.pop(0)
                    r = graph.nodes[nodoAAgregar]['radio']
                    rad = list(graph.nodes[nodoAAgregar]['posicion'])
                    rad.append(r)
                    nodoActual = Node( nodoAAgregar, radius =  rad)
                    nodoPadre.agregarHijo( nodoActual )
                    for vecino in grafo.neighbors( nodoAAgregar ):
                        if vecino != numeroNodoPadre:
                            aRecorrer.append( (vecino, nodoAAgregar,nodoActual) )
                subarboles.append(nodoRaiz)
                tortuosidad_generados.append(tortuosity(nodoRaiz))
            li = []
            generated_images.traverseInorderChilds(generated_images, li)
            two = [a for a in li if a == 2]
            n_bif_generados.append(len(two))
            count = []
            n = generated_images.countNodes(generated_images, count)
            n_nodes_generados.append(len(n))
            traverse(generated_images)
            
            total_path_length_value = tree_length(generated_images)
            #print("total_path_length_value", total_path_length_value)
            try:
                largo_generados.append(total_path_length_value.cpu().item())
            except:
                largo_generados.append(total_path_length_value)
            features = []
            
            traversefeatures(generated_images, features)
            ratio_radios_generados.append(sum(features)/len(features))
    return ratio_radios_generados, tortuosidad_generados, largo_generados

# %%
def cosine_similarity(vec1, vec2):
    #modificar con como la calcule yo
    dot_product = np.dot(vec1, vec2)
    norm_vec1 = np.linalg.norm(vec1)
    norm_vec2 = np.linalg.norm(vec2)
    return dot_product / (norm_vec1 * norm_vec2)

# %%
def confidence_interval(data, confidence=0.95):
    n = len(data)
    m = np.mean(data)
    std_err = sem(data)
    h = std_err * t.ppf((1 + confidence) / 2, n - 1)
    ci = t.interval(confidence, data)
    return m, m - h, m + h

def calculate_cosine_similarity_confidence_interval(n_iterations, latent_size, Grassdecoder, mult, confidence=0.95):
    cosine_similarity_valuesR = []
    cosine_similarity_valuesL = []
    cosine_similarity_valuesT = []
    emd_values_radios =[]
    emd_values_tortuosidad =[]
    emd_values_largo =[]

    for _ in range(n_iterations):
       
        ratio_radios_generados, tortuosidad_generados, largo_generados = calculo_generados(latent_size, Grassdecoder, mult)
        
        ###Histograma radio
        sns.displot([ratio_radios, ratio_radios_generados], multiple="dodge", height=10, aspect=1, legend=False, palette = enmax_palette)
        ax = plt.gca()
        patches = ax.patches
        l = int(len(patches)/2)
        patches_radius = patches[:l]
        patches_radius_generados = patches[l:]
        counts_radius = [patch.get_height() for patch in patches_radius]
        counts_radius_generados = [patch.get_height() for patch in patches_radius_generados]

        ##Histograma tortuosidad
        #tortuosidad_generados = [t for t in tortuosidad_generados if t<10]
        sns.displot([tortuosidad, tortuosidad_generados], multiple="dodge", height=10, aspect=1, legend=False, palette = enmax_palette, bins=50)
        ax = plt.gca()
        patches = ax.patches
        l = int(len(patches)/2)
        patches_tortuosidad = patches[:l]
        patches_tortuosidad_generados = patches[l:]
        counts_tortuosidad = [patch.get_height() for patch in patches_tortuosidad]
        counts_tortuosidad_generados = [patch.get_height() for patch in patches_tortuosidad_generados]

        ##Histograma largo
        sns.displot([largo, largo_generados], multiple="dodge", height=10, aspect=1, legend=False, palette=enmax_palette)
        ax = plt.gca()
        patches = ax.patches
        l = int(len(patches)/2)
        patches_length = patches[:l]
        patches_length_generados = patches[l:]
        counts = [patch.get_height() for patch in patches]
        counts_length = [patch.get_height() for patch in patches_length]
        counts_length_generados = [patch.get_height() for patch in patches_length_generados]

        
        cosine_sim_radios = cosine_similarity(counts_radius, counts_radius_generados)
        cosine_sim_tortuosidad = cosine_similarity(counts_tortuosidad,counts_tortuosidad_generados)
        cosine_sim_largo = cosine_similarity(counts_length, counts_length_generados)
        cosine_similarity_valuesR.append(cosine_sim_radios)
        cosine_similarity_valuesT.append(cosine_sim_tortuosidad)
        cosine_similarity_valuesL.append(cosine_sim_largo)

        # Calculate EMD (Wasserstein Distance)
        emd_radios = wasserstein_distance(range(len(counts_radius)), range(len(counts_radius_generados)), counts_radius, counts_radius_generados)
        emd_tortuosidad = wasserstein_distance(range(len(counts_tortuosidad)), range(len(counts_tortuosidad_generados)), counts_tortuosidad, counts_tortuosidad_generados)
        emd_largo = wasserstein_distance(range(len(counts_length)), range(len(counts_length_generados)), counts_length, counts_length_generados)
        
        # Append EMD values
        emd_values_radios.append(emd_radios)
        emd_values_tortuosidad.append(emd_tortuosidad)
        emd_values_largo.append(emd_largo)
    
    # Calculate confidence intervals
    resultR_e = confidence_interval(emd_values_radios, confidence)
    resultT_e = confidence_interval(emd_values_tortuosidad, confidence)
    resultL_e = confidence_interval(emd_values_largo, confidence)
    
    resultR = confidence_interval(cosine_similarity_valuesR, confidence)
    resultT = confidence_interval(cosine_similarity_valuesT, confidence)
    resultL = confidence_interval(cosine_similarity_valuesL, confidence)
    return resultR, resultL, resultT, resultR_e, resultT_e, resultL_e

# %%
a = [1.,1.,1.]
mult = torch.Tensor(a)
latent_size = 64
Grassdecoder = GRASSDecoder(latent_size=latent_size, hidden_size=256, mult = mult.to(device))
Grassdecoder = Grassdecoder.to(device)
Grassdecoder.eval()
checkpoint = torch.load("output/" + dataset_name + "P" +p + "eps" + eps+ "-best-nuevoweight.pth")
print(checkpoint['epoch'])

Grassdecoder.load_state_dict(checkpoint['decoder_state_dict'])
epoch = checkpoint['epoch']

#mean_cosine_similarity, lower_bound, upper_bounds, ratio_radios_generados = calculate_cosine_similarity_confidence_interval(10)
resultR, resultL, resultT, resultR_e, resultT_e, resultL_e = calculate_cosine_similarity_confidence_interval(10, latent_size, Grassdecoder, mult)
# Out:
# 12337
# /home/eiarussi/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:453: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure(figsize=figsize)

# %% [markdown]
# COsine similarity

# %%
mean, lower, upper = resultR
print("Radius")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
mean, lower, upper = resultT
print("Tortuosity")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
mean, lower, upper = resultL
print("Length")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
# Out:
# Radius
# mean 0.9
# bounds 0.88 0.92
# Tortuosity
# mean 0.6
# bounds 0.55 0.64
# Length
# mean 0.85
# bounds 0.82 0.87

# %% [markdown]
# EMD

# %%
mean, lower, upper = resultR_e
print("Radius")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
mean, lower, upper = resultT_e
print("Tortuosity")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
mean, lower, upper = resultL_e
print("Length")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
# Out:
# Radius
# mean 0.69
# bounds 0.52 0.85
# Tortuosity
# mean 5.4
# bounds 4.33 6.47
# Length
# mean 1.77
# bounds 1.59 1.94

# %%
'''from scipy.stats import wasserstein_distance
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def calculate_emd_confidence_interval(n_iterations, latent_size, Grassdecoder, mult, confidence=0.95):
    emd_values_radios = []
    emd_values_tortuosidad = []
    emd_values_largo = []

    for _ in range(n_iterations):
        # Assuming calculo_generados generates the synthetic data
        ratio_radios_generados, tortuosidad_generados, largo_generados = calculo_generados(latent_size, Grassdecoder, mult)
        
        ### Histogram for Radios
        sns.displot([ratio_radios, ratio_radios_generados], multiple="dodge", height=10, aspect=1, legend=False, palette="coolwarm", bins = 25)
        ax = plt.gca()
        patches = ax.patches
        l = int(len(patches)/2)
        patches_radius = patches[:l]
        patches_radius_generados = patches[l:]
        counts_radius = [patch.get_height() for patch in patches_radius]
        counts_radius_generados = [patch.get_height() for patch in patches_radius_generados]

        ### Histogram for Tortuosidad
        sns.displot([tortuosidad, tortuosidad_generados], multiple="dodge", height=10, aspect=1, legend=False, palette="coolwarm", bins = 25)
        ax = plt.gca()
        patches = ax.patches
        l = int(len(patches)/2)
        patches_tortuosidad = patches[:l]
        patches_tortuosidad_generados = patches[l:]
        counts_tortuosidad = [patch.get_height() for patch in patches_tortuosidad]
        counts_tortuosidad_generados = [patch.get_height() for patch in patches_tortuosidad_generados]

        ### Histogram for Largo
        sns.displot([largo, largo_generados], multiple="dodge", height=10, aspect=1, legend=False, palette="coolwarm", bins = 25)
        ax = plt.gca()
        patches = ax.patches
        l = int(len(patches)/2)
        patches_length = patches[:l]
        patches_length_generados = patches[l:]
        counts_length = [patch.get_height() for patch in patches_length]
        counts_length_generados = [patch.get_height() for patch in patches_length_generados]

        # Calculate EMD (Wasserstein Distance)
        emd_radios = wasserstein_distance(range(len(counts_radius)), range(len(counts_radius_generados)), counts_radius, counts_radius_generados)
        emd_tortuosidad = wasserstein_distance(range(len(counts_tortuosidad)), range(len(counts_tortuosidad_generados)), counts_tortuosidad, counts_tortuosidad_generados)
        emd_largo = wasserstein_distance(range(len(counts_length)), range(len(counts_length_generados)), counts_length, counts_length_generados)
        
        # Append EMD values
        emd_values_radios.append(emd_radios)
        emd_values_tortuosidad.append(emd_tortuosidad)
        emd_values_largo.append(emd_largo)
    
    # Calculate confidence intervals
    resultR = confidence_interval(emd_values_radios, confidence)
    resultT = confidence_interval(emd_values_tortuosidad, confidence)
    resultL = confidence_interval(emd_values_largo, confidence)

    return resultR, resultL, resultT

resultR, resultL, resultT = calculate_emd_confidence_interval(10, latent_size, Grassdecoder, mult)'''
# Out:
# 'from scipy.stats import wasserstein_distance\nimport numpy as np\nimport seaborn as sns\nimport matplotlib.pyplot as plt\n\ndef calculate_emd_confidence_interval(n_iterations, latent_size, Grassdecoder, mult, confidence=0.95):\n    emd_values_radios = []\n    emd_values_tortuosidad = []\n    emd_values_largo = []\n\n    for _ in range(n_iterations):\n        # Assuming calculo_generados generates the synthetic data\n        ratio_radios_generados, tortuosidad_generados, largo_generados = calculo_generados(latent_size, Grassdecoder, mult)\n        \n        ### Histogram for Radios\n        sns.displot([ratio_radios, ratio_radios_generados], multiple="dodge", height=10, aspect=1, legend=False, palette="coolwarm", bins = 25)\n        ax = plt.gca()\n        patches = ax.patches\n        l = int(len(patches)/2)\n        patches_radius = patches[:l]\n        patches_radius_generados = patches[l:]\n        counts_radius = [patch.get_height() for patch in patches_radius]\n        counts_radius_generados = [patch.get_height() for patch in patches_radius_generados]\n\n        ### Histogram for Tortuosidad\n        sns.displot([tortuosidad, tortuosidad_generados], multiple="dodge", height=10, aspect=1, legend=False, palette="coolwarm", bins = 25)\n        ax = plt.gca()\n        patches = ax.patches\n        l = int(len(patches)/2)\n        patches_tortuosidad = patches[:l]\n        patches_tortuosidad_generados = patches[l:]\n        counts_tortuosidad = [patch.get_height() for patch in patches_tortuosidad]\n        counts_tortuosidad_generados = [patch.get_height() for patch in patches_tortuosidad_generados]\n\n        ### Histogram for Largo\n        sns.displot([largo, largo_generados], multiple="dodge", height=10, aspect=1, legend=False, palette="coolwarm", bins = 25)\n        ax = plt.gca()\n        patches = ax.patches\n        l = int(len(patches)/2)\n        patches_length = patches[:l]\n        patches_length_generados = patches[l:]\n        counts_length = [patch.get_height() for patch in patches_length]\n        counts_length_generados = [patch.get_height() for patch in patches_length_generados]\n\n        # Calculate EMD (Wasserstein Distance)\n        emd_radios = wasserstein_distance(range(len(counts_radius)), range(len(counts_radius_generados)), counts_radius, counts_radius_generados)\n        emd_tortuosidad = wasserstein_distance(range(len(counts_tortuosidad)), range(len(counts_tortuosidad_generados)), counts_tortuosidad, counts_tortuosidad_generados)\n        emd_largo = wasserstein_distance(range(len(counts_length)), range(len(counts_length_generados)), counts_length, counts_length_generados)\n        \n        # Append EMD values\n        emd_values_radios.append(emd_radios)\n        emd_values_tortuosidad.append(emd_tortuosidad)\n        emd_values_largo.append(emd_largo)\n    \n    # Calculate confidence intervals\n    resultR = confidence_interval(emd_values_radios, confidence)\n    resultT = confidence_interval(emd_values_tortuosidad, confidence)\n    resultL = confidence_interval(emd_values_largo, confidence)\n\n    return resultR, resultL, resultT\n\nresultR, resultL, resultT = calculate_emd_confidence_interval(10, latent_size, Grassdecoder, mult)'

# %%
mean, lower, upper = resultR
print("Radius")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
mean, lower, upper = resultT
print("Tortuosity")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
mean, lower, upper = resultL
print("Length")
print("mean", np.round(mean,2))
print("bounds", np.round(lower,2), np.round(upper,2))
# Out:
# Radius
# mean 0.9
# bounds 0.88 0.92
# Tortuosity
# mean 0.6
# bounds 0.55 0.64
# Length
# mean 0.85
# bounds 0.82 0.87

# %% [markdown]
# Per branch statistics

# %%
def traverse_and_collect_branches(node, current_branch, branches):
    if not node:
        return
    
    # Extract the radius from the fourth position of the tensor
    current_branch.append(node.radius[3].item())
    
    # If it's a leaf or a bifurcation, store the branch and start new branches
    if (node.left and node.right) or (not node.left and not node.right):
        if current_branch:
            branches.append(current_branch[:])
        current_branch.clear()

    if node.left:
        traverse_and_collect_branches(node.left, current_branch[:], branches)
    if node.right:
        traverse_and_collect_branches(node.right, current_branch[:], branches)

def calculate_branch_average(branch):
    return sum(branch) / len(branch) if branch else 0

def check_murrays_law(node):
    branches = []
    traverse_and_collect_branches(node, [], branches)
    
    for i in range(1, len(branches)):
        parent_avg = calculate_branch_average(branches[i - 1])
        left_child_avg = calculate_branch_average(branches[i]) if i < len(branches) else 0
        right_child_avg = calculate_branch_average(branches[i + 1]) if i + 1 < len(branches) else 0
        
        # Check Murray's Law
        murray_respect = parent_avg**3 == left_child_avg**3 + right_child_avg**3
        
        print(f"Bifurcation {i}:")
        print(f"  Parent average radius: {parent_avg:.4f}")
        print(f"  Left child average radius: {left_child_avg:.4f}")
        print(f"  Right child average radius: {right_child_avg:.4f}")
        print(f"  children sum: {left_child_avg**3 + right_child_avg**3:.4f}")
        print(f"  parent: {parent_avg**3:.4f}")
        print(f"  Respects Murray's Law: {'Yes' if murray_respect else 'No'}\n")



# Example usage

for batch in data_loader:
    for t_l, input in enumerate(batch):
        if t_l > 1:
            break
        check_murrays_law(input)
        print(t_l)
# Out:
# Bifurcation 1:
#   Parent average radius: 0.0085
#   Left child average radius: 0.0089
#   Right child average radius: 0.0083
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0089
#   Left child average radius: 0.0083
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0110
#   Left child average radius: 0.0115
#   Right child average radius: 0.0124
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0115
#   Left child average radius: 0.0124
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0175
#   Left child average radius: 0.0175
#   Right child average radius: 0.0187
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0175
#   Left child average radius: 0.0187
#   Right child average radius: 0.0040
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0187
#   Left child average radius: 0.0040
#   Right child average radius: 0.0149
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0040
#   Left child average radius: 0.0149
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0075
#   Left child average radius: 0.0053
#   Right child average radius: 0.0086
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0053
#   Left child average radius: 0.0086
#   Right child average radius: 0.0099
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0086
#   Left child average radius: 0.0099
#   Right child average radius: 0.0107
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0099
#   Left child average radius: 0.0107
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0076
#   Left child average radius: 0.0089
#   Right child average radius: 0.0085
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0089
#   Left child average radius: 0.0085
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0073
#   Left child average radius: 0.0097
#   Right child average radius: 0.0096
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0097
#   Left child average radius: 0.0096
#   Right child average radius: 0.0073
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0096
#   Left child average radius: 0.0073
#   Right child average radius: 0.0076
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0073
#   Left child average radius: 0.0076
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0077
#   Left child average radius: 0.0087
#   Right child average radius: 0.0234
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0087
#   Left child average radius: 0.0234
#   Right child average radius: 0.0147
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0234
#   Left child average radius: 0.0147
#   Right child average radius: 0.0133
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0147
#   Left child average radius: 0.0133
#   Right child average radius: 0.0282
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0133
#   Left child average radius: 0.0282
#   Right child average radius: 0.0181
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0282
#   Left child average radius: 0.0181
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0085
#   Left child average radius: 0.0104
#   Right child average radius: 0.0060
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0104
#   Left child average radius: 0.0060
#   Right child average radius: 0.0058
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0060
#   Left child average radius: 0.0058
#   Right child average radius: 0.0118
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0058
#   Left child average radius: 0.0118
#   Right child average radius: 0.0218
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0118
#   Left child average radius: 0.0218
#   Right child average radius: 0.0221
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0218
#   Left child average radius: 0.0221
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0067
#   Left child average radius: 0.0116
#   Right child average radius: 0.0197
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0116
#   Left child average radius: 0.0197
#   Right child average radius: 0.0205
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0197
#   Left child average radius: 0.0205
#   Right child average radius: 0.0070
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0205
#   Left child average radius: 0.0070
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0073
#   Left child average radius: 0.0093
#   Right child average radius: 0.0045
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0093
#   Left child average radius: 0.0045
#   Right child average radius: 0.0229
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0045
#   Left child average radius: 0.0229
#   Right child average radius: 0.0074
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0229
#   Left child average radius: 0.0074
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0064
#   Left child average radius: 0.0067
#   Right child average radius: 0.0064
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0067
#   Left child average radius: 0.0064
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0094
#   Left child average radius: 0.0118
#   Right child average radius: 0.0138
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0118
#   Left child average radius: 0.0138
#   Right child average radius: 0.0111
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0138
#   Left child average radius: 0.0111
#   Right child average radius: 0.0097
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0111
#   Left child average radius: 0.0097
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0093
#   Left child average radius: 0.0095
#   Right child average radius: 0.0098
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0095
#   Left child average radius: 0.0098
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0065
#   Left child average radius: 0.0039
#   Right child average radius: 0.0153
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0039
#   Left child average radius: 0.0153
#   Right child average radius: 0.0212
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0153
#   Left child average radius: 0.0212
#   Right child average radius: 0.0228
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0212
#   Left child average radius: 0.0228
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0461
#   Left child average radius: 0.0390
#   Right child average radius: 0.0462
#   children sum: 0.0002
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0390
#   Left child average radius: 0.0462
#   Right child average radius: 0.0000
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0078
#   Left child average radius: 0.0232
#   Right child average radius: 0.0224
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0232
#   Left child average radius: 0.0224
#   Right child average radius: 0.0220
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0224
#   Left child average radius: 0.0220
#   Right child average radius: 0.0074
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0220
#   Left child average radius: 0.0074
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0111
#   Left child average radius: 0.0145
#   Right child average radius: 0.0088
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0145
#   Left child average radius: 0.0088
#   Right child average radius: 0.0126
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0088
#   Left child average radius: 0.0126
#   Right child average radius: 0.0102
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0126
#   Left child average radius: 0.0102
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0206
#   Left child average radius: 0.0224
#   Right child average radius: 0.0189
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0224
#   Left child average radius: 0.0189
#   Right child average radius: 0.0186
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0189
#   Left child average radius: 0.0186
#   Right child average radius: 0.0066
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0186
#   Left child average radius: 0.0066
#   Right child average radius: 0.0141
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0066
#   Left child average radius: 0.0141
#   Right child average radius: 0.0222
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0141
#   Left child average radius: 0.0222
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0525
#   Left child average radius: 0.0423
#   Right child average radius: 0.0327
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0423
#   Left child average radius: 0.0327
#   Right child average radius: 0.0419
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0327
#   Left child average radius: 0.0419
#   Right child average radius: 0.0407
#   children sum: 0.0001
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0419
#   Left child average radius: 0.0407
#   Right child average radius: 0.0301
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0407
#   Left child average radius: 0.0301
#   Right child average radius: 0.0241
#   children sum: 0.0000
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0301
#   Left child average radius: 0.0241
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0091
#   Left child average radius: 0.0094
#   Right child average radius: 0.0095
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0094
#   Left child average radius: 0.0095
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0215
#   Left child average radius: 0.0221
#   Right child average radius: 0.0057
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0221
#   Left child average radius: 0.0057
#   Right child average radius: 0.0214
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0057
#   Left child average radius: 0.0214
#   Right child average radius: 0.0217
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0214
#   Left child average radius: 0.0217
#   Right child average radius: 0.0050
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0217
#   Left child average radius: 0.0050
#   Right child average radius: 0.0226
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0050
#   Left child average radius: 0.0226
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0285
#   Left child average radius: 0.0290
#   Right child average radius: 0.0066
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0290
#   Left child average radius: 0.0066
#   Right child average radius: 0.0289
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0066
#   Left child average radius: 0.0289
#   Right child average radius: 0.0296
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0289
#   Left child average radius: 0.0296
#   Right child average radius: 0.0118
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0296
#   Left child average radius: 0.0118
#   Right child average radius: 0.0272
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0118
#   Left child average radius: 0.0272
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0106
#   Left child average radius: 0.0130
#   Right child average radius: 0.0073
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0130
#   Left child average radius: 0.0073
#   Right child average radius: 0.0097
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0073
#   Left child average radius: 0.0097
#   Right child average radius: 0.0111
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0097
#   Left child average radius: 0.0111
#   Right child average radius: 0.0058
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0111
#   Left child average radius: 0.0058
#   Right child average radius: 0.0108
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0058
#   Left child average radius: 0.0108
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0212
#   Left child average radius: 0.0212
#   Right child average radius: 0.0064
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0212
#   Left child average radius: 0.0064
#   Right child average radius: 0.0216
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0064
#   Left child average radius: 0.0216
#   Right child average radius: 0.0136
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0216
#   Left child average radius: 0.0136
#   Right child average radius: 0.0190
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0136
#   Left child average radius: 0.0190
#   Right child average radius: 0.0219
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0190
#   Left child average radius: 0.0219
#   Right child average radius: 0.0070
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 7:
#   Parent average radius: 0.0219
#   Left child average radius: 0.0070
#   Right child average radius: 0.0228
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 8:
#   Parent average radius: 0.0070
#   Left child average radius: 0.0228
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0096
#   Left child average radius: 0.0121
#   Right child average radius: 0.0112
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0121
#   Left child average radius: 0.0112
#   Right child average radius: 0.0077
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0112
#   Left child average radius: 0.0077
#   Right child average radius: 0.0093
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0077
#   Left child average radius: 0.0093
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0086
#   Left child average radius: 0.0113
#   Right child average radius: 0.0101
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0113
#   Left child average radius: 0.0101
#   Right child average radius: 0.0120
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0101
#   Left child average radius: 0.0120
#   Right child average radius: 0.0095
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0120
#   Left child average radius: 0.0095
#   Right child average radius: 0.0060
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0095
#   Left child average radius: 0.0060
#   Right child average radius: 0.0078
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0060
#   Left child average radius: 0.0078
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0185
#   Left child average radius: 0.0182
#   Right child average radius: 0.0207
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0182
#   Left child average radius: 0.0207
#   Right child average radius: 0.0222
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0207
#   Left child average radius: 0.0222
#   Right child average radius: 0.0147
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0222
#   Left child average radius: 0.0147
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0140
#   Left child average radius: 0.0310
#   Right child average radius: 0.0305
#   children sum: 0.0001
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0310
#   Left child average radius: 0.0305
#   Right child average radius: 0.0102
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0305
#   Left child average radius: 0.0102
#   Right child average radius: 0.0288
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0102
#   Left child average radius: 0.0288
#   Right child average radius: 0.0283
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0288
#   Left child average radius: 0.0283
#   Right child average radius: 0.0189
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0283
#   Left child average radius: 0.0189
#   Right child average radius: 0.0273
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 7:
#   Parent average radius: 0.0189
#   Left child average radius: 0.0273
#   Right child average radius: 0.0149
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 8:
#   Parent average radius: 0.0273
#   Left child average radius: 0.0149
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0236
#   Left child average radius: 0.0249
#   Right child average radius: 0.0203
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0249
#   Left child average radius: 0.0203
#   Right child average radius: 0.0178
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0203
#   Left child average radius: 0.0178
#   Right child average radius: 0.0309
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0178
#   Left child average radius: 0.0309
#   Right child average radius: 0.0344
#   children sum: 0.0001
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0309
#   Left child average radius: 0.0344
#   Right child average radius: 0.0161
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0344
#   Left child average radius: 0.0161
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0357
#   Left child average radius: 0.0381
#   Right child average radius: 0.0375
#   children sum: 0.0001
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0381
#   Left child average radius: 0.0375
#   Right child average radius: 0.0161
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0375
#   Left child average radius: 0.0161
#   Right child average radius: 0.0387
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0161
#   Left child average radius: 0.0387
#   Right child average radius: 0.0273
#   children sum: 0.0001
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0387
#   Left child average radius: 0.0273
#   Right child average radius: 0.0154
#   children sum: 0.0000
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0273
#   Left child average radius: 0.0154
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0095
#   Left child average radius: 0.0121
#   Right child average radius: 0.0141
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0121
#   Left child average radius: 0.0141
#   Right child average radius: 0.0061
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0141
#   Left child average radius: 0.0061
#   Right child average radius: 0.0116
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0061
#   Left child average radius: 0.0116
#   Right child average radius: 0.0109
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0116
#   Left child average radius: 0.0109
#   Right child average radius: 0.0051
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0109
#   Left child average radius: 0.0051
#   Right child average radius: 0.0079
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 7:
#   Parent average radius: 0.0051
#   Left child average radius: 0.0079
#   Right child average radius: 0.0070
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 8:
#   Parent average radius: 0.0079
#   Left child average radius: 0.0070
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0069
#   Left child average radius: 0.0219
#   Right child average radius: 0.0209
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0219
#   Left child average radius: 0.0209
#   Right child average radius: 0.0209
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0209
#   Left child average radius: 0.0209
#   Right child average radius: 0.0069
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0209
#   Left child average radius: 0.0069
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0024
#   Left child average radius: 0.0000
#   Right child average radius: 0.0055
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0000
#   Left child average radius: 0.0055
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0216
#   Left child average radius: 0.0266
#   Right child average radius: 0.0240
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0266
#   Left child average radius: 0.0240
#   Right child average radius: 0.0144
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0240
#   Left child average radius: 0.0144
#   Right child average radius: 0.0226
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0144
#   Left child average radius: 0.0226
#   Right child average radius: 0.0104
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0226
#   Left child average radius: 0.0104
#   Right child average radius: 0.0194
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0104
#   Left child average radius: 0.0194
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0208
#   Left child average radius: 0.0208
#   Right child average radius: 0.0206
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0208
#   Left child average radius: 0.0206
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0281
#   Left child average radius: 0.0295
#   Right child average radius: 0.0124
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0295
#   Left child average radius: 0.0124
#   Right child average radius: 0.0253
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0124
#   Left child average radius: 0.0253
#   Right child average radius: 0.0286
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0253
#   Left child average radius: 0.0286
#   Right child average radius: 0.0055
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0286
#   Left child average radius: 0.0055
#   Right child average radius: 0.0289
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0055
#   Left child average radius: 0.0289
#   Right child average radius: 0.0225
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 7:
#   Parent average radius: 0.0289
#   Left child average radius: 0.0225
#   Right child average radius: 0.0308
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 8:
#   Parent average radius: 0.0225
#   Left child average radius: 0.0308
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0168
#   Left child average radius: 0.0001
#   Right child average radius: 0.0233
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0001
#   Left child average radius: 0.0233
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0265
#   Left child average radius: 0.0288
#   Right child average radius: 0.0104
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0288
#   Left child average radius: 0.0104
#   Right child average radius: 0.0278
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0104
#   Left child average radius: 0.0278
#   Right child average radius: 0.0276
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0278
#   Left child average radius: 0.0276
#   Right child average radius: 0.0189
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0276
#   Left child average radius: 0.0189
#   Right child average radius: 0.0242
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0189
#   Left child average radius: 0.0242
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0040
#   Left child average radius: 0.0176
#   Right child average radius: 0.0172
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0176
#   Left child average radius: 0.0172
#   Right child average radius: 0.0170
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0172
#   Left child average radius: 0.0170
#   Right child average radius: 0.0026
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0170
#   Left child average radius: 0.0026
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0078
#   Left child average radius: 0.0075
#   Right child average radius: 0.0088
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0075
#   Left child average radius: 0.0088
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0132
#   Left child average radius: 0.0132
#   Right child average radius: 0.0162
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0132
#   Left child average radius: 0.0162
#   Right child average radius: 0.0211
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0162
#   Left child average radius: 0.0211
#   Right child average radius: 0.0186
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0211
#   Left child average radius: 0.0186
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0260
#   Left child average radius: 0.0281
#   Right child average radius: 0.0136
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0281
#   Left child average radius: 0.0136
#   Right child average radius: 0.0084
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0136
#   Left child average radius: 0.0084
#   Right child average radius: 0.0108
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0084
#   Left child average radius: 0.0108
#   Right child average radius: 0.0252
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0108
#   Left child average radius: 0.0252
#   Right child average radius: 0.0298
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0252
#   Left child average radius: 0.0298
#   Right child average radius: 0.0307
#   children sum: 0.0001
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 7:
#   Parent average radius: 0.0298
#   Left child average radius: 0.0307
#   Right child average radius: 0.0215
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 8:
#   Parent average radius: 0.0307
#   Left child average radius: 0.0215
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0064
#   Left child average radius: 0.0020
#   Right child average radius: 0.0076
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0020
#   Left child average radius: 0.0076
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0376
#   Left child average radius: 0.0424
#   Right child average radius: 0.0139
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0424
#   Left child average radius: 0.0139
#   Right child average radius: 0.0465
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0139
#   Left child average radius: 0.0465
#   Right child average radius: 0.0471
#   children sum: 0.0002
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0465
#   Left child average radius: 0.0471
#   Right child average radius: 0.0351
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0471
#   Left child average radius: 0.0351
#   Right child average radius: 0.0377
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0351
#   Left child average radius: 0.0377
#   Right child average radius: 0.0000
#   children sum: 0.0001
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0210
#   Left child average radius: 0.0210
#   Right child average radius: 0.0207
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0210
#   Left child average radius: 0.0207
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0105
#   Left child average radius: 0.0111
#   Right child average radius: 0.0042
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0111
#   Left child average radius: 0.0042
#   Right child average radius: 0.0093
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0042
#   Left child average radius: 0.0093
#   Right child average radius: 0.0105
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0093
#   Left child average radius: 0.0105
#   Right child average radius: 0.0105
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0105
#   Left child average radius: 0.0105
#   Right child average radius: 0.0040
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0105
#   Left child average radius: 0.0040
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0207
#   Left child average radius: 0.0209
#   Right child average radius: 0.0055
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0209
#   Left child average radius: 0.0055
#   Right child average radius: 0.0206
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0055
#   Left child average radius: 0.0206
#   Right child average radius: 0.0214
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0206
#   Left child average radius: 0.0214
#   Right child average radius: 0.0193
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0214
#   Left child average radius: 0.0193
#   Right child average radius: 0.0120
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0193
#   Left child average radius: 0.0120
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0145
#   Left child average radius: 0.0161
#   Right child average radius: 0.0165
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0161
#   Left child average radius: 0.0165
#   Right child average radius: 0.0077
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0165
#   Left child average radius: 0.0077
#   Right child average radius: 0.0150
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0077
#   Left child average radius: 0.0150
#   Right child average radius: 0.0071
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0150
#   Left child average radius: 0.0071
#   Right child average radius: 0.0138
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0071
#   Left child average radius: 0.0138
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0062
#   Left child average radius: 0.0112
#   Right child average radius: 0.0223
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0112
#   Left child average radius: 0.0223
#   Right child average radius: 0.0212
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0223
#   Left child average radius: 0.0212
#   Right child average radius: 0.0045
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0212
#   Left child average radius: 0.0045
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0175
#   Left child average radius: 0.0076
#   Right child average radius: 0.0148
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0076
#   Left child average radius: 0.0148
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0143
#   Left child average radius: 0.0143
#   Right child average radius: 0.0139
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0143
#   Left child average radius: 0.0139
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0228
#   Left child average radius: 0.0240
#   Right child average radius: 0.0232
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0240
#   Left child average radius: 0.0232
#   Right child average radius: 0.0075
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0232
#   Left child average radius: 0.0075
#   Right child average radius: 0.0229
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0075
#   Left child average radius: 0.0229
#   Right child average radius: 0.0220
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0229
#   Left child average radius: 0.0220
#   Right child average radius: 0.0209
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0220
#   Left child average radius: 0.0209
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0211
#   Left child average radius: 0.0229
#   Right child average radius: 0.0206
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0229
#   Left child average radius: 0.0206
#   Right child average radius: 0.0190
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0206
#   Left child average radius: 0.0190
#   Right child average radius: 0.0099
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0190
#   Left child average radius: 0.0099
#   Right child average radius: 0.0116
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0099
#   Left child average radius: 0.0116
#   Right child average radius: 0.0070
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0116
#   Left child average radius: 0.0070
#   Right child average radius: 0.0100
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 7:
#   Parent average radius: 0.0070
#   Left child average radius: 0.0100
#   Right child average radius: 0.0219
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 8:
#   Parent average radius: 0.0100
#   Left child average radius: 0.0219
#   Right child average radius: 0.0076
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 9:
#   Parent average radius: 0.0219
#   Left child average radius: 0.0076
#   Right child average radius: 0.0211
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 10:
#   Parent average radius: 0.0076
#   Left child average radius: 0.0211
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0425
#   Left child average radius: 0.0434
#   Right child average radius: 0.0111
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0434
#   Left child average radius: 0.0111
#   Right child average radius: 0.0419
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0111
#   Left child average radius: 0.0419
#   Right child average radius: 0.0433
#   children sum: 0.0002
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0419
#   Left child average radius: 0.0433
#   Right child average radius: 0.0126
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0433
#   Left child average radius: 0.0126
#   Right child average radius: 0.0437
#   children sum: 0.0001
#   parent: 0.0001
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0126
#   Left child average radius: 0.0437
#   Right child average radius: 0.0000
#   children sum: 0.0001
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0099
#   Left child average radius: 0.0104
#   Right child average radius: 0.0086
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0104
#   Left child average radius: 0.0086
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0218
#   Left child average radius: 0.0224
#   Right child average radius: 0.0159
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0224
#   Left child average radius: 0.0159
#   Right child average radius: 0.0255
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0159
#   Left child average radius: 0.0255
#   Right child average radius: 0.0210
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0255
# ...
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0218
#   Left child average radius: 0.0206
#   Right child average radius: 0.0114
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0206
#   Left child average radius: 0.0114
#   Right child average radius: 0.0078
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0114
#   Left child average radius: 0.0078
#   Right child average radius: 0.0092
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0078
#   Left child average radius: 0.0092
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0082
#   Left child average radius: 0.0074
#   Right child average radius: 0.0100
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0074
#   Left child average radius: 0.0100
#   Right child average radius: 0.0062
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0100
#   Left child average radius: 0.0062
#   Right child average radius: 0.0100
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0062
#   Left child average radius: 0.0100
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# 0
# Bifurcation 1:
#   Parent average radius: 0.0097
#   Left child average radius: 0.0124
#   Right child average radius: 0.0106
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0124
#   Left child average radius: 0.0106
#   Right child average radius: 0.0060
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0106
#   Left child average radius: 0.0060
#   Right child average radius: 0.0100
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0060
#   Left child average radius: 0.0100
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0099
#   Left child average radius: 0.0143
#   Right child average radius: 0.0169
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0143
#   Left child average radius: 0.0169
#   Right child average radius: 0.0083
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0169
#   Left child average radius: 0.0083
#   Right child average radius: 0.0100
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0083
#   Left child average radius: 0.0100
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0219
#   Left child average radius: 0.0225
#   Right child average radius: 0.0213
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0225
#   Left child average radius: 0.0213
#   Right child average radius: 0.0074
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0213
#   Left child average radius: 0.0074
#   Right child average radius: 0.0220
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0074
#   Left child average radius: 0.0220
#   Right child average radius: 0.0223
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0220
#   Left child average radius: 0.0223
#   Right child average radius: 0.0264
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0223
#   Left child average radius: 0.0264
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0053
#   Left child average radius: 0.0030
#   Right child average radius: 0.0052
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0030
#   Left child average radius: 0.0052
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0137
#   Left child average radius: 0.0143
#   Right child average radius: 0.0186
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0143
#   Left child average radius: 0.0186
#   Right child average radius: 0.0068
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0186
#   Left child average radius: 0.0068
#   Right child average radius: 0.0143
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0068
#   Left child average radius: 0.0143
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0076
#   Left child average radius: 0.0080
#   Right child average radius: 0.0080
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0080
#   Left child average radius: 0.0080
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0095
#   Left child average radius: 0.0096
#   Right child average radius: 0.0095
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0096
#   Left child average radius: 0.0095
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0102
#   Left child average radius: 0.0101
#   Right child average radius: 0.0098
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0101
#   Left child average radius: 0.0098
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0069
#   Left child average radius: 0.0064
#   Right child average radius: 0.0068
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0064
#   Left child average radius: 0.0068
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0162
#   Left child average radius: 0.0164
#   Right child average radius: 0.0180
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0164
#   Left child average radius: 0.0180
#   Right child average radius: 0.0152
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0180
#   Left child average radius: 0.0152
#   Right child average radius: 0.0140
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0152
#   Left child average radius: 0.0140
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0086
#   Left child average radius: 0.0088
#   Right child average radius: 0.0085
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0088
#   Left child average radius: 0.0085
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0212
#   Left child average radius: 0.0237
#   Right child average radius: 0.0204
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0237
#   Left child average radius: 0.0204
#   Right child average radius: 0.0137
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0204
#   Left child average radius: 0.0137
#   Right child average radius: 0.0211
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0137
#   Left child average radius: 0.0211
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0097
#   Left child average radius: 0.0103
#   Right child average radius: 0.0099
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0103
#   Left child average radius: 0.0099
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0203
#   Left child average radius: 0.0208
#   Right child average radius: 0.0208
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0208
#   Left child average radius: 0.0208
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0141
#   Left child average radius: 0.0114
#   Right child average radius: 0.0148
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0114
#   Left child average radius: 0.0148
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0088
#   Left child average radius: 0.0185
#   Right child average radius: 0.0185
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0185
#   Left child average radius: 0.0185
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0214
#   Left child average radius: 0.0213
#   Right child average radius: 0.0199
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0213
#   Left child average radius: 0.0199
#   Right child average radius: 0.0057
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0199
#   Left child average radius: 0.0057
#   Right child average radius: 0.0209
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0057
#   Left child average radius: 0.0209
#   Right child average radius: 0.0062
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0209
#   Left child average radius: 0.0062
#   Right child average radius: 0.0198
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0062
#   Left child average radius: 0.0198
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0105
#   Left child average radius: 0.0113
#   Right child average radius: 0.0092
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0113
#   Left child average radius: 0.0092
#   Right child average radius: 0.0079
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0092
#   Left child average radius: 0.0079
#   Right child average radius: 0.0109
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0079
#   Left child average radius: 0.0109
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0123
#   Left child average radius: 0.0137
#   Right child average radius: 0.0080
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0137
#   Left child average radius: 0.0080
#   Right child average radius: 0.0191
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0080
#   Left child average radius: 0.0191
#   Right child average radius: 0.0125
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0191
#   Left child average radius: 0.0125
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0138
#   Left child average radius: 0.0182
#   Right child average radius: 0.0180
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0182
#   Left child average radius: 0.0180
#   Right child average radius: 0.0178
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0180
#   Left child average radius: 0.0178
#   Right child average radius: 0.0120
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0178
#   Left child average radius: 0.0120
#   Right child average radius: 0.0109
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0120
#   Left child average radius: 0.0109
#   Right child average radius: 0.0126
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0109
#   Left child average radius: 0.0126
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0126
#   Left child average radius: 0.0100
#   Right child average radius: 0.0118
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0100
#   Left child average radius: 0.0118
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0080
#   Left child average radius: 0.0083
#   Right child average radius: 0.0076
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0083
#   Left child average radius: 0.0076
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
# Bifurcation 1:
#   Parent average radius: 0.0114
#   Left child average radius: 0.0273
#   Right child average radius: 0.0240
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 2:
#   Parent average radius: 0.0273
#   Left child average radius: 0.0240
#   Right child average radius: 0.0248
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 3:
#   Parent average radius: 0.0240
#   Left child average radius: 0.0248
#   Right child average radius: 0.0124
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 4:
#   Parent average radius: 0.0248
#   Left child average radius: 0.0124
#   Right child average radius: 0.0092
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 5:
#   Parent average radius: 0.0124
#   Left child average radius: 0.0092
#   Right child average radius: 0.0080
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# Bifurcation 6:
#   Parent average radius: 0.0092
#   Left child average radius: 0.0080
#   Right child average radius: 0.0000
#   children sum: 0.0000
#   parent: 0.0000
#   Respects Murray's Law: No
#
# 0
